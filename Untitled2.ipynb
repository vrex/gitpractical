# %%
import os
os.environ["OMP_NUM_THREADS"] = "1"

# %%
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

tsne = TSNE(
    n_components=2,
    random_state=42,
    perplexity=5
)

tsne_vectors = tsne.fit_transform(word_vectors)

plt.figure(figsize=(10,8))

for i, word in enumerate(words):
    
    x = tsne_vectors[i][0]
    y = tsne_vectors[i][1]
    
    plt.scatter(x, y)
    plt.text(x+0.5, y+0.5, word)

plt.title("t-SNE Visualization")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 10
#       2 import matplotlib.pyplot as plt
#       4 tsne = TSNE(
#       5     n_components=2,
#       6     random_state=42,
#       7     perplexity=5
#       8 )
# ---> 10 tsne_vectors = tsne.fit_transform(word_vectors)
#      12 plt.figure(figsize=(10,8))
#      14 for i, word in enumerate(words):
#
# NameError: name 'word_vectors' is not defined
